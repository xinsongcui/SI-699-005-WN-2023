# %%
# !pip install sqlite_s3_query
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 KB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 7.2 MB/s eta 0:00:00
# ...

# %%
from functools import partial
from sqlite_s3_query import sqlite_s3_query
import pandas as pd

# %%
def get_credentials(_):
    return (
        'us-east-1',
        'ASIAYJ5HVX6RY4OC744Z',                                                                                    
        '/MwBP88ZDsIMeI2FIA/NH3xdw+1vOOp+uznom4if',                                                                       
        ''
    )

# %%
query_my_db = partial(sqlite_s3_query,
    url='https://xinsongbucket1.s3.us-east-1.amazonaws.com/games.db',
    get_credentials=get_credentials,
)

with \
        query_my_db() as query, \
        query('SELECT * FROM games WHERE platform = ? And score > ?', params=('Switch', '90',)) as (columns, rows):

    #for row in rows:
    #    print(row)
    df = pd.DataFrame(rows, columns=columns)

# %%
df
# Out:
#     index                                               name  \
# 0    1000            The Legend of Zelda: Breath of the Wild
# 1    1001                                Super Mario Odyssey
# 2    1002                        Portal Companion Collection
# 3    1003  The House in Fata Morgana - Dreams of the Reve...
# 4    1004                           Metroid Prime Remastered
# 5    1005                           Tetris Effect: Connected
# 6    1006                                    Persona 5 Royal
# 7    1007                                              Hades
# 8    1008     Divinity: Original Sin II - Definitive Edition
# 9    1009                      Ori and the Will of the Wisps
# 10   1010                                          Undertale
# 11   1011                         Super Smash Bros. Ultimate
# 12   1012                                            Celeste
# 13   1013                             A Monster's Expedition
# ...
